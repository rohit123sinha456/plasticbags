# %%
import pickle
import matplotlib.pyplot as plt

# %%
with open("Server_training/plasticbags/test", "rb") as fp:   # Unpickling
    hist = pickle.load(fp)
    plt.figure()
    plt.ylabel("Loss (training and validation)")
    plt.xlabel("Training Steps")
    plt.ylim([0,2])
    plt.plot(hist["loss"])
    plt.plot(hist["val_loss"])

    plt.figure()
    plt.ylabel("Accuracy (training and validation)")
    plt.xlabel("Training Steps")
    plt.ylim([0,1])
    plt.plot(hist["accuracy"])
    plt.plot(hist["val_accuracy"])

# %%
import tensorflow as tf

# %%
model = tf.keras.models.load_model("trained_model")
# Out:
# ---------------------------------------------------------------------------
# JSONDecodeError                           Traceback (most recent call last)
# <ipython-input-2-fcbbd7c779e3> in <module>
# ----> 1 model = tf.keras.models.load_model("trained_model")
#
# c:\software\sdk\Anaconda3\lib\site-packages\tensorflow\python\keras\saving\save.py in load_model(filepath, custom_objects, compile, options)
#     185     if isinstance(filepath, six.string_types):
#     186       loader_impl.parse_saved_model(filepath)
# --> 187       return saved_model_load.load(filepath, compile, options)
#     188
#     189   raise IOError(
#
# c:\software\sdk\Anaconda3\lib\site-packages\tensorflow\python\keras\saving\saved_model\load.py in load(path, compile, options)
#     118   # TODO(kathywu): Add code to load from objects that contain all endpoints
#     119
# --> 120   model = tf_load.load_internal(
#     121       path, options=options, loader_cls=KerasObjectLoader)
#     122
#
# c:\software\sdk\Anaconda3\lib\site-packages\tensorflow\python\saved_model\load.py in load_internal(export_dir, tags, options, loader_cls)
#     630     with ops.init_scope():
#     631       try:
# --> 632         loader = loader_cls(object_graph_proto, saved_model_proto, export_dir,
#     633                             ckpt_options)
#     634       except errors.NotFoundError as err:
#
# c:\software\sdk\Anaconda3\lib\site-packages\tensorflow\python\keras\saving\saved_model\load.py in __init__(self, *args, **kwargs)
#     192     self._models_to_reconstruct = []
#     193
# --> 194     super(KerasObjectLoader, self).__init__(*args, **kwargs)
#     195
#     196     # Now that the node object has been fully loaded, and the checkpoint has
#
# c:\software\sdk\Anaconda3\lib\site-packages\tensorflow\python\saved_model\load.py in __init__(self, object_graph_proto, saved_model_proto, export_dir, ckpt_options)
#     128       self._concrete_functions[name] = _WrapperFunction(concrete_function)
#     129
# --> 130     self._load_all()
#     131     self._restore_checkpoint()
#     132
#
# c:\software\sdk\Anaconda3\lib\site-packages\tensorflow\python\keras\saving\saved_model\load.py in _load_all(self)
#     213     # loaded from config may create variables / other objects during
#     214     # initialization. These are recorded in `_nodes_recreated_from_config`.
# --> 215     self._layer_nodes = self._load_layers()
#     216
#     217     # Load all other nodes and functions.
#
# c:\software\sdk\Anaconda3\lib\site-packages\tensorflow\python\keras\saving\saved_model\load.py in _load_layers(self)
#     313         continue
#     314
# --> 315       layers[node_id] = self._load_layer(proto.user_object, node_id)
#     316
#     317     for node_id, proto in metric_list:
#
# c:\software\sdk\Anaconda3\lib\site-packages\tensorflow\python\keras\saving\saved_model\load.py in _load_layer(self, proto, node_id)
#     321   def _load_layer(self, proto, node_id):
#     322     """Load a single layer from a SavedUserObject proto."""
# --> 323     metadata = json_utils.decode(proto.metadata)
#     324
#     325     # If node was already created
#
# c:\software\sdk\Anaconda3\lib\site-packages\tensorflow\python\keras\saving\saved_model\json_utils.py in decode(json_string)
#      58
#      59 def decode(json_string):
# ---> 60   return json.loads(json_string, object_hook=_decode_helper)
#      61
#      62
#
# c:\software\sdk\Anaconda3\lib\json\__init__.py in loads(s, cls, object_hook, parse_float, parse_int, parse_constant, object_pairs_hook, **kw)
#     368     if parse_constant is not None:
#     369         kw['parse_constant'] = parse_constant
# --> 370     return cls(**kw).decode(s)
#
# c:\software\sdk\Anaconda3\lib\json\decoder.py in decode(self, s, _w)
#     335
#     336         """
# --> 337         obj, end = self.raw_decode(s, idx=_w(s, 0).end())
#     338         end = _w(s, end).end()
#     339         if end != len(s):
#
# c:\software\sdk\Anaconda3\lib\json\decoder.py in raw_decode(self, s, idx)
#     353             obj, end = self.scan_once(s, idx)
#     354         except StopIteration as err:
# --> 355             raise JSONDecodeError("Expecting value", s, err.value) from None
#     356         return obj, end
#
# JSONDecodeError: Expecting value: line 1 column 1 (char 0)

# %%
print(tf.__version__)
# Out:
# 2.3.0

# %%
import cv2
import numpy as np
img = cv2.imread("pbg.jpg")
img_processed = np.resize(img,(512,512,3))
img_processed - np.expand_dims(img_processed,axis=0)
pred = model(img_processed)
print(pred)
